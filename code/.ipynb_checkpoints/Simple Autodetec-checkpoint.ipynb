# %%
# %matplotlib inline

import os 
import time
import librosa
import librosa.display
import importlib
import matplotlib
import numpy as np
import string as strp
import pr_util as util

import matplotlib.pyplot as plt

importlib.reload(util)

# %%
y, sr = librosa.load('Rexp/100041.filtered1.wav')

# %%
print(len(y))
matplotlib.pyplot.plot(y)
# Out:
# 178432

# %%
matplotlib.pyplot.plot(np.abs(y))

# %%
matplotlib.pyplot.plot(np.abs(y)**2)

# %%
def autodetec(y, power, thres):
    N = len(y)
    y_env = np.abs(y) ** power
    y2 = np.zeros(N)
    y2[y_env <= thres] = 1
    y2[y_env  > thres] = 2
    y3 = (y2[:-1] + y2[1:]).copy()
    y3[0] = 3
    y3[-1] = 3
    return np.where(y3 == 3)[0]

markers_on = autodetec(y, 2, 0.2)

# %%
plt.plot(y, '-gD', markevery = markers_on.tolist())

# %%
def plot_with_marks(y, power, thres, n_fft, save_pic = False):
    markers_on = autodetec(y, power, thres)
    markers_on = markers_on.tolist()
    D = librosa.stft(y, hop_length = n_fft, n_fft = n_fft)
    #print(D.shape)
    #print(np.max(D))
    D = librosa.amplitude_to_db(D, ref=np.max)
    print(D.shape)
    M, N = D.shape
    #print(np.min(D))
    
    for frame in markers_on:
        #print(int(np.floor(frame/n_fft)))
        D[:int(M/20), int(np.floor(frame/n_fft))] = 10
        
    #D[:,200] = -80
    librosa.display.specshow(D, y_axis='log', x_axis='time')
    plt.title('Power spectrogram')
    plt.colorbar(format='%+2.0f dB')
    plt.tight_layout()
    if (save_pic): plt.savefig("../pics/file.power_{}.thres_{}.nfft_{}.svg".format(power, thres, n_fft))
        


#plot_with_marks(y, 2, 0.2, 2048)

# %%
#for i in range(100):
#    for pot in range(1, 5):
#        time.sleep(0.100)
#        plot_with_marks(y, pot, i/100.0, 2048)
#        plt.close('all')
y, sr = librosa.load('Rexp/100041.filtered1.wav')
plot_with_marks(y, 1, 0.07, 2048)
# Out:
# (1025, 88)

# %%
file_dirs = util.return(1)

print(file_dir)
y, sr = librosa.load(file_dir[0])
plot_with_marks(y, 1, 0.07, 2048)
# Out:
# ['/Users/felipefelix/USP/tcc/dataset/pr_article/S_A_C_Base_Parte-4/Trichothraupis melanops/']
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-34-2e6a15fdbfa0> in <module>()
#       1 file_dir = util.choose_species(1)
#       2 print(file_dir)
# ----> 3 y, sr = librosa.load(file_dir[0])
#       4 plot_with_marks(y, 1, 0.07, 2048)
#
# /Users/felipefelix/anaconda3/lib/python3.5/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     105
#     106     y = []
# --> 107     with audioread.audio_open(os.path.realpath(path)) as input_file:
#     108         sr_native = input_file.samplerate
#     109         n_channels = input_file.channels
#
# /Users/felipefelix/anaconda3/lib/python3.5/site-packages/audioread/__init__.py in audio_open(path)
#      76     from . import rawread
#      77     try:
# ---> 78         return rawread.RawAudioFile(path)
#      79     except DecodeError:
#      80         pass
#
# /Users/felipefelix/anaconda3/lib/python3.5/site-packages/audioread/rawread.py in __init__(self, filename)
#      47     """
#      48     def __init__(self, filename):
# ---> 49         self._fh = open(filename, 'rb')
#      50
#      51         try:
#
# IsADirectoryError: [Errno 21] Is a directory: '/Users/felipefelix/USP/tcc/dataset/pr_article/S_A_C_Base_Parte-4/Trichothraupis melanops'
